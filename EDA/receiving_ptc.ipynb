# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from data_load import load_aggregate_data, get_user_tasks
from distance_map import load_distance_map
from gridload import load_grid_graph, plot_grid
from data_analyze import calculate_metrics
import numpy as np
import json

# %% [markdown]
# # EDA with Receiving -> PTC Data

# %%
df = pd.read_csv("Dock-PTC Data/DC820 to PTC.csv")

# %% [markdown]
# ## Remove/rename columns

# %%
cols = [df.columns[0], "WHSE", "NBR_OF_CASES", "NBR_UNITS", "MENU_OPTN_NAME"]
for col in cols:
    try:
        df.drop(columns=[col], inplace=True)
    except:
        continue
df
# Out:
#         CNTR_NBR TO_LOCN FROM_LOCN       CREATE_DATE    USER_ID
# 0      BM9325112     631      075R  2024-02-19 00:10   ggonzale
# 1      BM9325114     631      075R  2024-02-19 00:10   ggonzale
# 2      BM9325111     631      075R  2024-02-19 00:11   ggonzale
# 3      BM9325110     631      075R  2024-02-19 00:15   ggonzale
# 4      BM9325108     631      075R  2024-02-19 00:22   ggonzale
# ...          ...     ...       ...               ...        ...
# 91444  BM8383721     631      061R  2024-06-17 15:43      ebrea
# 91445  BH9618610     641       NaN  2024-06-17 15:43  achampion
# 91446  BM9219077     641      137R  2024-06-17 15:43    rpierre
# 91447  BM8384582     641      051R  2024-06-17 15:44   jkanicki
# 91448  BM0228222     641      117R  2024-06-17 15:50      ebrea
#
# [91449 rows x 5 columns]

# %%
renames = {
    "CNTR_NBR" : "id", 
    "TO_LOCN" : "to_locn",
    "FROM_LOCN" : "from_locn",
    "CREATE_DATE" : "from_time",
    "USER_ID" : "user",
}
try:
    df.rename(columns=renames, inplace=True)
except:
    print("Rename not successful")

# %% [markdown]
# ## Format times and clean bad rows

# %%
df["from_time"] = pd.to_datetime(df["from_time"])

# %%
original = df.shape[0]
df = df[df["to_locn"] != df["from_locn"]]
new = df.shape[0]
print(f"Removed {original - new} rows")
# Out:
# Removed 4302 rows

# %%
original = df.shape[0]
df.dropna(subset=["from_locn"], inplace=True)
new = df.shape[0]
print(f"Removed {original - new} rows")
# Out:
# Removed 2358 rows
# C:\Users\ctang\AppData\Local\Temp\1\ipykernel_17056\137836925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["from_locn"], inplace=True)

# %% [markdown]
# ## Exploring data in cols

# %%
df1 = df[df["from_locn"].str.contains("692")]
df1
# Out:
#               id to_locn from_locn         from_time        user
# 1909   BW9803259     631    692002  2024-02-21 17:13     eperez1
# 1910   BW9803258     631    692009  2024-02-21 17:13     eperez1
# 1911   BW9803257     631    692029  2024-02-21 17:13     eperez1
# 1912   BW9803256     631    692036  2024-02-21 17:13     eperez1
# 1913   BW9803255     631    692037  2024-02-21 17:13     eperez1
# 1914   BW9803254     631    692040  2024-02-21 17:14     eperez1
# 1915   BW9803253     631    692045  2024-02-21 17:14     eperez1
# 1916   BW9803252     631    692061  2024-02-21 17:14     eperez1
# 1945   BW9661946     631    692034  2024-02-21 17:34     eperez1
# 1946   BW9661945     631    692044  2024-02-21 17:35     eperez1
# 1947   BW9661944     631    692069  2024-02-21 17:35     eperez1
# 6760   BM9759257     631    692007  2024-02-27 23:55    jgarcia2
# 27437  BF0343398     631    692020  2024-03-22 19:21    jgarcia2
# 63179  BH0059182     631    692009  2024-05-09 16:23      aramos
# 63302  BT0039369     631    692052  2024-05-09 20:34     nvaldez
# 63311  BT0039384     631    692125  2024-05-09 20:43     nvaldez
# 68876  BH0058223     641    692002  2024-05-17 16:56      aramos
# 77471  BT6681548     641    692014  2024-05-29 21:56  grodriguez
# 77616  BT6681638     641    692082  2024-05-30 00:49  grodriguez
# 84579  BH0071511     631    692029  2024-06-07 17:47     nvaldez
# 90325  BF0385443     631    692097  2024-06-14 21:42    fsanchez
# 90332  BF0385463     631    692102  2024-06-14 21:59     nvaldez

# %%
set(df["from_locn"])
# Out:
# {'002A003',
#  '002A008',
#  '002A014',
#  '002A029',
#  '002A030',
#  '002A036',
#  '002A037',
#  '002A039',
#  '002B017',
#  '002R',
#  '003A007',
#  '003A008',
#  '003A017',
#  '003A024',
#  '003A027',
#  '003B001',
#  '003B004',
#  '003C015',
#  '003D011',
#  '003D016',
#  '003E041',
#  '003L001',
#  '003L004',
#  '003R',
#  '004A025',
#  '004A027',
#  '004A030',
#  '004A039',
#  '004B036',
#  '004E027',
#  '004L001',
#  '004L002',
#  '004R',
#  '005A002',
#  '005A005',
#  '005A006',
#  '005A031',
#  '005B000',
#  '005B018',
#  '005C025',
#  '005L000',
#  '005L004',
#  '005M003',
#  '005R',
#  '006A003',
#  '006A005',
#  '006A021',
#  '006A024',
#  '006B021',
#  '006B038',
#  '006R',
#  '007A009',
#  '007A010',
#  '007A017',
#  '007A020',
#  '007A021',
#  '007A030',
#  '007A033',
#  '007A039',
#  '007C006',
#  '007D005',
#  '007E014',
#  '007M001',
#  '007M004',
#  '007R',
#  '008A007',
#  '008A030',
#  '008A031',
#  '008A038',
#  '008L001',
#  '008L002',
#  '008R',
#  '009A000',
#  '009A001',
#  '009A008',
#  '009A010',
#  '009A034',
#  '009A040',
#  '009A042',
#  '009B020',
#  '009B032',
#  '009L003',
#  '009R',
#  '010A000',
#  '010A015',
#  '010A029',
#  '010L001',
#  '010R',
#  '011A003',
#  '011A015',
#  '011A016',
#  '011A022',
#  '011A033',
#  '011A037',
#  '011A040',
#  '011B020',
#  '011B033',
#  '011C012',
#  '011L003',
#  '011M003',
#  '011R',
#  '012A000',
#  '012A010',
#  '012A014',
#  '012A020',
#  '012B000',
#  '012B001',
#  '012B027',
#  '012C005',
#  '012D000',
#  '012L002',
#  '012R',
#  '013A004',
#  '013A029',
#  '013A032',
#  '013A040',
#  '013B004',
#  '014A012',
#  '014A013',
#  '014A018',
#  '014A023',
#  '014A034',
#  '014A035',
#  '014A042',
#  '014L002',
#  '015A002',
#  '015A004',
#  '015A035',
#  '015B003',
#  '015B034',
#  '015D001',
#  '015L001',
#  '015L003',
#  '015L019',
#  '016A010',
#  '016A022',
#  '016A035',
#  '016A036',
#  '016L000',
#  '016R',
#  '017A003',
#  '017A015',
#  '017A020',
#  '017A025',
#  '017A032',
#  '017L002',
#  '017L003',
#  '017L004',
#  '017R',
#  '018A012',
#  '018C002',
#  '018E035',
#  '018L000',
#  '018L001',
#  '018R',
#  '019A006',
#  '019A014',
#  '019A024',
#  '019R',
#  '020A015',
#  '020A033',
#  '020C005',
#  '020C028',
#  '020R',
#  '021A002',
#  '021A011',
#  '021A016',
#  '021A024',
#  '021B041',
#  '021L004',
#  '021L020',
#  '021R',
#  '022A001',
#  '022A023',
#  '022B001',
#  '022R',
#  '023A002',
#  '023A010',
#  '023A028',
#  '023L000',
#  '024A009',
#  '024B004',
#  '024B011',
#  '024B013',
#  '024B017',
#  '024D040',
#  '024E039',
#  '024R',
#  '025A011',
#  '025A028',
#  '025B032',
#  '026A022',
#  '026A038',
#  '026B021',
#  '026B040',
#  '026C022',
#  '027A006',
#  '027A009',
#  '027A034',
#  '034S',
#  '035A001',
#  '035A004',
#  '035A013',
#  '035A020',
#  '035B036',
#  '035C011',
#  '035D020',
#  '035D023',
#  '036A002',
#  '036A011',
#  '036A033',
#  '036A044',
#  '036A045',
#  '036A051',
#  '036B018',
#  '036C029',
#  '037A018',
#  '037A022',
#  '037A046',
#  '037A052',
#  '037B005',
#  '037B006',
#  '037B011',
#  '037B012',
#  '037B017',
#  '037B018',
#  '037B019',
#  '037B020',
#  '037B021',
#  '037B030',
#  '037C006',
#  '037D023',
#  '038A003',
#  '038A018',
#  '038L000',
#  '038L002',
#  '038M002',
#  '039A004',
#  '039A036',
#  '039A053',
#  '040A024',
#  '040A030',
#  '040A031',
#  '040A044',
#  '040A047',
#  '040L001',
#  '040L002',
#  '041A027',
#  '041A030',
#  '041C027',
#  '041C039',
#  '041D013',
#  '041L001',
#  '042A017',
#  '042A018',
#  '042A034',
#  '042A050',
#  '042B003',
#  '042L000',
#  '042L001',
#  '042L010',
#  '043A027',
#  '043A031',
#  '043A032',
#  '043A035',
#  '043A038',
#  '043L000',
#  '044A005',
#  '044A006',
#  '044A018',
#  '044A024',
#  '044A028',
#  '044A030',
#  '044A048',
#  '044A050',
#  '044B002',
#  '044L000',
#  '044L009',
#  '045A005',
#  '045A010',
#  '045A017',
#  '045A022',
#  '045B050',
#  '045C042',
#  '045D047',
#  '045E044',
#  '045L002',
#  '046A029',
#  '046A054',
#  '046C018',
#  '046L001',
#  '047A000',
#  '047A001',
#  '047A009',
#  '047A023',
#  '047A042',
#  '047A048',
#  '047L002',
#  '047R',
#  '048A007',
#  '048A010',
#  '048A015',
#  '048A041',
#  '048A047',
#  '048A049',
#  '048L000',
#  '048L001',
#  '049A004',
#  '049A005',
#  '049A006',
#  '049A007',
#  '049A008',
#  '049A011',
#  '049A020',
#  '049A024',
#  '049A026',
#  '049A028',
#  '049A042',
#  '049D045',
#  '049D051',
#  '049L000',
#  '049L002',
#  '049R',
#  '050A004',
#  '050A009',
#  '050A017',
#  '050A028',
#  '050A034',
#  '050A052',
#  '050B047',
#  '050C043',
#  '050L001',
#  '051A002',
#  '051A003',
#  '051A004',
#  '051A008',
#  '051A009',
#  '051A010',
#  '051A011',
#  '051A015',
#  '051A018',
#  '051A019',
#  '051A031',
#  '051A032',
#  '051A033',
#  '051A034',
#  '051A042',
#  '051A048',
#  '051A049',
#  '051A054',
#  '051L001',
#  '051L002',
#  '051R',
#  '052A000',
#  '052A012',
#  '052A017',
#  '052A025',
#  '052A029',
#  '052A031',
#  '052A044',
#  '052A050',
#  '052A052',
#  '052B006',
#  '052B038',
#  '052L001',
#  '052L002',
#  '052M002',
#  '053A010',
#  '053A025',
#  '053A033',
#  '053A040',
#  '053A046',
#  '053A053',
#  '053B009',
#  '053B031',
#  '053B045',
#  '053B051',
#  '053C001',
#  '053E000',
#  '053L001',
#  '053R',
#  '054A006',
#  '054A007',
#  '054A008',
#  '054A011',
#  '054A012',
#  '054A013',
#  '054A014',
#  '054A015',
#  '054A016',
#  '054A017',
#  '054A019',
#  '054A022',
#  '054A025',
#  '054A028',
#  '054A036',
#  '054A037',
#  '054A039',
#  '054A043',
#  '054A044',
#  '054A046',
#  '054A047',
#  '054A049',
#  '054A053',
#  '054B022',
#  '054B046',
#  '054C022',
#  '054C028',
#  '054E000',
#  '054L000',
#  '054L001',
#  '054L002',
#  '054M001',
#  '054M002',
#  '055R',
#  '057R',
#  '061R',
#  '063R',
#  '065R',
#  '066S',
#  '067R',
#  '069R',
#  '071R',
#  '073R',
#  '075R',
#  '077R',
#  '079R',
#  '081R',
#  '083R',
#  '085R',
#  '087R',
#  '089R',
#  '090R',
#  '091R',
#  '092R',
#  '093R',
#  '094R',
#  '095R',
#  '096R',
#  '097R',
#  '098R',
#  '099R',
#  '100R',
#  '105R',
#  '107R',
#  '109R',
#  '111R',
#  '112R',
#  '113R',
#  '115R',
#  '117R',
#  '118R',
#  '119R',
#  '120R',
#  '121R',
#  '123R',
#  '125R',
#  '127R',
#  '129R',
#  '131R',
#  '133R',
#  '135R',
#  '137R',
#  '138R',
#  '139R',
#  '145S',
#  '171S',
#  '173R',
#  '175R',
#  '177R',
#  '179R',
#  '181R',
#  '183R',
#  '185R',
#  '187R',
#  '189R',
#  '191R',
#  '193R',
#  '197S',
#  '200D',
#  '214R',
#  '215Q13',
#  '215Q45',
#  '215Q53',
#  '216946X',
#  '223R',
#  '228B07',
#  '231R',
#  '233R',
#  '237S003',
#  '244A06',
#  '244B09',
#  '256A09',
#  '256A17',
#  '260EC02',
#  '265V12',
#  '631',
#  '641',
#  '651',
#  '661',
#  '681',
#  '692002',
#  '692007',
#  '692009',
#  '692014',
#  '692020',
#  '692029',
#  '692034',
#  '692036',
#  '692037',
#  '692040',
#  '692044',
#  '692045',
#  '692052',
#  '692061',
#  '692069',
#  '692082',
#  '692097',
#  '692102',
#  '692125',
#  '734',
#  '735',
#  '8731441',
#  'BRK1',
#  'IBNP',
#  'MNOB',
#  'PTC',
#  'S01A003',
#  'S01A005',
#  'S01A006',
#  'S01B001',
#  'S01B002',
#  'S01B003',
#  'S01B004',
#  'S01B005',
#  'S01B006',
#  'S01B007',
#  'S01D005',
#  'S02A003',
#  'S02A005',
#  'S02A007',
#  'S02A008',
#  'S02B010',
#  'S02E002',
#  'S03B001',
#  'S03B004',
#  'S03B006',
#  'S03C003',
#  'SCAL',
#  'problem'}

# %% [markdown]
# ## Filter out specifics from location column and standardize values

# %%
# filter out from_locn
df = df[ (df['from_locn'].str.endswith('R')) |  # Condition 1
                        (df['from_locn'].str.startswith('C')) |  # Condition 2
                        (df['from_locn'].str.endswith('S')) |  # Condition 3
                        (df['from_locn'].isin(['BRK','INBP','MNOB', 'BRK1'])) |  # Condition 4
                        (df['from_locn'].astype(str).str.contains('692|682')) | 
                        (df['from_locn'].str.startswith('6')) | 
                        (df['from_locn'].isin([611, 621, 631, 641, 651, 661, 671, 681, 691]))]  
# remove trailing Rs and make 682/692*** onnly 682
def h(x):
    if x[-1] == 'R':
        return x[:-1]
    if x[-1] == 'S':
        return x[:-1]
    elif len(x) == 6 and x[0] == '6':
        return x[:3]
    else:
        return x
df["from_locn"] = df["from_locn"].apply(h)
df["from_locn"]
# Out:
# 0        075
# 1        075
# 2        075
# 3        075
# 4        075
#         ...
# 91443    113
# 91444    061
# 91446    137
# 91447    051
# 91448    117
# Name: from_locn, Length: 84154, dtype: object

# %%
set(df["to_locn"])
# Out:
# {'631', '641', '651', '661'}

# %%
# filter to_locn so only between 600 and 700
df = df[df["to_locn"].isin(["611", "621", "631", "641", "651", "661", "671", "681", "691"])]
